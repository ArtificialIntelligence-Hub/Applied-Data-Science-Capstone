# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png"  width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
# <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01" target="_blank">Spacex DataSet</a>

# %% [markdown]
# ### Store the dataset in database table
#
# **it is highly recommended to manually load the table using the database console LOAD tool in DB2**.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload.png">
#
# Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the  dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new table as follows:
#
# **SPACEXDATASET**
#
# **Follow these steps while using old DB2 UI which is having Open Console Screen**
#
# **Note:While loading Spacex dataset, ensure that detect datatypes is disabled. Later click on the pencil icon(edit option).**
#
# 1.  Change the Date Format by manually typing DD-MM-YYYY and timestamp format as DD-MM-YYYY HH\:MM:SS.
#
#     Here you should place the cursor at Date field and manually type as DD-MM-YYYY.
#
# 2.  Change the PAYLOAD_MASS\_\_KG\_  datatype  to INTEGER.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload2.png">

# %% [markdown]
# **Changes to be considered when having DB2 instance with the new UI having Go to UI screen**
#
# *   Refer to this insruction in this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sign%20up%20for%20IBM%20Cloud%20-%20Create%20Db2%20service%20instance%20-%20Get%20started%20with%20the%20Db2%20console/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">link</a> for viewing  the new  Go to UI screen.
#
# *   Later click on **Data link(below SQL)**  in the Go to UI screen  and click on **Load Data** tab.
#
# *   Later browse for the downloaded spacex file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/browsefile.png" width="800"/>
#
# *   Once done select the schema andload the file.
#
#  <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload3.png" width="800"/>

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# !pip install ipython-sql
# Out:
# Collecting sqlalchemy==1.3.9
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp39-cp39-win_amd64.whl size=1142938 sha256=74b2ae0989d6bdb0b38aaca15eec9795888fa5db7f37709b161f5e4e93037ebb
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\5b\43\0d\de1699809f9e6aaa54a97275298fa07075cb19acc557b18955
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.32
#     Uninstalling SQLAlchemy-1.4.32:
#       Successfully uninstalled SQLAlchemy-1.4.32
# Successfully installed sqlalchemy-1.3.9
# Collecting ibm_db_sa
#   Downloading ibm_db_sa-0.3.9-py3-none-any.whl (30 kB)
# Requirement already satisfied: sqlalchemy>=0.7.3 in c:\users\user\anaconda3\lib\site-packages (from ibm_db_sa) (1.3.9)
# Collecting ibm-db>=2.0.0
#   Downloading ibm_db-3.1.4.tar.gz (1.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Building wheels for collected packages: ibm-db
#   Building wheel for ibm-db (PEP 517): started
#   Building wheel for ibm-db (PEP 517): finished with status 'error'
# Failed to build ibm-db
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\User\anaconda3\python.exe' 'C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\User\AppData\Local\Temp\tmpfj3q_f4u'
#        cwd: C:\Users\User\AppData\Local\Temp\pip-install-71jk6752\ibm-db_f90b4cf759d2408b85a5147281e82671
#   Complete output (1384 lines):
#   Detected 64-bit Python
#   Detected platform = win32
#   running bdist_wheel
#   running build
#   running build_py
#   copying ibmdb_tests.py -> build\lib
#   creating build\lib\clidriver
#   copying clidriver\__init__.py -> build\lib\clidriver
#   copying ibm_db_dlls\__init__.py -> build\lib\ibm_db_dlls
#   copying ibm_db_tests\test_52949_TestSPIntVarcharXml.py -> build\lib\ibm_db_tests
#   running egg_info
#   writing ibm_db.egg-info\PKG-INFO
#   writing dependency_links to ibm_db.egg-info\dependency_links.txt
#   writing top-level names to ibm_db.egg-info\top_level.txt
#   reading manifest file 'ibm_db.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files found matching 'config.py'
#   adding license file 'LICENSE'
#   writing manifest file 'ibm_db.egg-info\SOURCES.txt'
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin.icc64' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin.icc64' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin.icc64' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin.icc64' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin.icc64.c.icc' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin.icc64.c.icc' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin.icc64.c.icc' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin.icc64.c.icc' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin.icc64.c.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin.icc64.c.icc.icclib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin.icc64.c.icc.icclib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin.icc64.c.icc.icclib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin.icc64.n.icc' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin.icc64.n.icc' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin.icc64.n.icc' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin.icc64.n.icc' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin.icc64.n.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin.icc64.n.icc.icclib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin.icc64.n.icc.icclib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin.icc64.n.icc.icclib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bnd' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bnd' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bnd' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bnd' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.cfg' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.cfg' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.cfg' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.cfg' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.alt' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.alt' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.conv.alt' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.alt' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.ms' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.ms' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.conv.ms' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.ms' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.db2' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.db2' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.db2' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.db2' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.include' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.include' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.include' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.include' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.lib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.license' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.license' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.license.Windows' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license.Windows' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.license.Windows' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license.Windows' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.msg.en_US' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.msg.en_US' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.msg.en_US' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.msg.en_US' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.properties.version' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.properties.version' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.properties.version' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.properties.version' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\Users\User\AppData\Local\Temp\pip-build-env-iko3hbbd\overlay\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.security.plugin.IBM.client' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.security.plugin.IBM.client' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.security.plugin.IBM.client' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.security.plugin.IBM.client' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   creating build\lib\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll.2.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.APP64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLI64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLIXML4C64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAP64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAPM64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBM.DB2.SEC64.manifest -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMIAMauth64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMLDAPauthclient64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMOSauthclient64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMOSauthclientTwoPart64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMkrb564.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\IBMkrb5TwoPart64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2app64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2cli.exe -> build\lib\clidriver\bin
#   copying clidriver\bin\db2cli64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2clixml4c64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2ldap64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2ldapm64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2level.exe -> build\lib\clidriver\bin
#   copying clidriver\bin\db2osse64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2support.exe -> build\lib\clidriver\bin
#   copying clidriver\bin\db2trc.exe -> build\lib\clidriver\bin
#   copying clidriver\bin\db2trcapi64.dll -> build\lib\clidriver\bin
#   copying clidriver\bin\db2trcd64.exe -> build\lib\clidriver\bin
#   creating build\lib\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\amd64.VC12.CRT.manifest -> build\lib\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcp120.dll -> build\lib\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcr120.dll -> build\lib\clidriver\bin\amd64.VC12.CRT
#   creating build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8acmeidup_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8cms_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8dbfl_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8drld_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8iccs_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8kicc_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8km2_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8km_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8ldap_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8msca_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8mscng_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8p11_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8ssl_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8sys_64.dll -> build\lib\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8valn_64.dll -> build\lib\clidriver\bin\icc64
#   creating build\lib\clidriver\bin\icc64\c
#   creating build\lib\clidriver\bin\icc64\c\icc
#   copying clidriver\bin\icc64\c\icc\ReadMe.txt -> build\lib\clidriver\bin\icc64\c\icc
#   creating build\lib\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\ICCSIG.txt -> build\lib\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\icclib084.dll -> build\lib\clidriver\bin\icc64\c\icc\icclib
#   creating build\lib\clidriver\bin\icc64\n
#   creating build\lib\clidriver\bin\icc64\n\icc
#   copying clidriver\bin\icc64\n\icc\ReadMe.txt -> build\lib\clidriver\bin\icc64\n\icc
#   creating build\lib\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\ICCSIG.txt -> build\lib\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\icclib085.dll -> build\lib\clidriver\bin\icc64\n\icc\icclib
#   creating build\lib\clidriver\bnd
#   copying clidriver\bnd\db2ajgrt.bnd -> build\lib\clidriver\bnd
#   copying clidriver\bnd\db2cli.bnd -> build\lib\clidriver\bnd
#   copying clidriver\bnd\db2cli.lst -> build\lib\clidriver\bnd
#   copying clidriver\bnd\db2clipk.bnd -> build\lib\clidriver\bnd
#   copying clidriver\bnd\db2clist.bnd -> build\lib\clidriver\bnd
#   copying clidriver\bnd\db2spcdb.bnd -> build\lib\clidriver\bnd
#   creating build\lib\clidriver\cfg
#   copying clidriver\cfg\DigiCertGlobalRootCA.arm -> build\lib\clidriver\cfg
#   copying clidriver\cfg\db2dsdriver.xsd -> build\lib\clidriver\cfg
#   creating build\lib\clidriver\conv
#   creating build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\04370923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\08500923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\08501252.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\08600923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\08630923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09230437.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09230850.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09230860.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231043.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231051.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231114.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231208.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231252.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09231275.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09241252.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\09370950.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\10430923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\10510923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\11140923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\12080923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\12520850.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\12520923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\12750923.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\1388ucs2.cnv -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00850.ucs -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00923.ucs -> build\lib\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM01252.ucs -> build\lib\clidriver\conv\alt
#   creating build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\0930ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\0939ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\0943ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\0954ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\1390ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\1399ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\5039ucs2.cnv -> build\lib\clidriver\conv\ms
#   copying clidriver\conv\ms\ucs20943.cnv -> build\lib\clidriver\conv\ms
#   creating build\lib\clidriver\db2
#   copying clidriver\db2\db2diag.log -> build\lib\clidriver\db2
#   creating build\lib\clidriver\include
#   copying clidriver\include\sql.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlca.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlcli.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlcli1.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlda.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlenv.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlext.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlstate.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlsystm.h -> build\lib\clidriver\include
#   copying clidriver\include\sqltypes.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlucode.h -> build\lib\clidriver\include
#   copying clidriver\include\sqlunx.h -> build\lib\clidriver\include
#   creating build\lib\clidriver\lib
#   copying clidriver\lib\db2app64.lib -> build\lib\clidriver\lib
#   copying clidriver\lib\db2cli64.lib -> build\lib\clidriver\lib
#   creating build\lib\clidriver\license
#   copying clidriver\license\odbc_REDIST.txt -> build\lib\clidriver\license
#   copying clidriver\license\odbc_notices.rtf -> build\lib\clidriver\license
#   creating build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib\clidriver\license\Windows
#   creating build\lib\clidriver\msg
#   creating build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2adm.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2admh.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2caem.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cklog.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cli.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clia1.lst -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clias.lst -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clih.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clit.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp2.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2fodc.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sql.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sqlh.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2stt.mo -> build\lib\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2supp.mo -> build\lib\clidriver\msg\en_US
#   creating build\lib\clidriver\properties
#   creating build\lib\clidriver\properties\version
#   copying clidriver\properties\version\ibm.com_IBM_Data_Server_Driver_for_ODBC_and_CLI-11.5.0.swidtag -> build\lib\clidriver\properties\version
#   creating build\lib\clidriver\security
#   creating build\lib\clidriver\security\plugin
#   creating build\lib\clidriver\security\plugin\IBM
#   creating build\lib\clidriver\security\plugin\IBM\client
#   copying clidriver\security\plugin\IBM\client\IBMIAMauth64.dll -> build\lib\clidriver\security\plugin\IBM\client
#   copying ibm_db_dlls\ibm_db.dll -> build\lib\ibm_db_dlls
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\certs
#   copying build\lib\certs\ibm_certs.pem -> build\bdist.win-amd64\wheel\.\certs
#   copying build\lib\certs\__init__.py -> build\bdist.win-amd64\wheel\.\certs
#   creating build\bdist.win-amd64\wheel\clidriver
#   creating build\bdist.win-amd64\wheel\clidriver\bin
#   creating build\bdist.win-amd64\wheel\clidriver\bin\amd64.VC12.CRT
#   copying build\lib\clidriver\bin\amd64.VC12.CRT\amd64.VC12.CRT.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin\amd64.VC12.CRT
#   copying build\lib\clidriver\bin\amd64.VC12.CRT\msvcp120.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\amd64.VC12.CRT
#   copying build\lib\clidriver\bin\amd64.VC12.CRT\msvcr120.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\amd64.VC12.CRT
#   copying build\lib\clidriver\bin\db2app64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2cli.exe -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2cli64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2clixml4c64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2ldap64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2ldapm64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2level.exe -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2osse64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2support.exe -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2trc.exe -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2trcapi64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\db2trcd64.exe -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\DB2xml4c_cli64_5_8.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\DB2xml4c_cli64_5_8.dll.2.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.APP64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.CLI64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.CLIXML4C64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.LDAP64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.LDAPM64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBM.DB2.SEC64.manifest -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMIAMauth64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMkrb564.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMkrb5TwoPart64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMLDAPauthclient64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMOSauthclient64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   copying build\lib\clidriver\bin\IBMOSauthclientTwoPart64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\c
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\c\icc
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\c\icc\icclib
#   copying build\lib\clidriver\bin\icc64\c\icc\icclib\icclib084.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\c\icc\icclib
#   copying build\lib\clidriver\bin\icc64\c\icc\icclib\ICCSIG.txt -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\c\icc\icclib
#   copying build\lib\clidriver\bin\icc64\c\icc\ReadMe.txt -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\c\icc
#   copying build\lib\clidriver\bin\icc64\gsk8acmeidup_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8cms_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8dbfl_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8drld_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8iccs_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8kicc_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8km2_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8km_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8ldap_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8msca_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8mscng_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8p11_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8ssl_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8sys_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   copying build\lib\clidriver\bin\icc64\gsk8valn_64.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\n
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\n\icc
#   creating build\bdist.win-amd64\wheel\clidriver\bin\icc64\n\icc\icclib
#   copying build\lib\clidriver\bin\icc64\n\icc\icclib\icclib085.dll -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\n\icc\icclib
#   copying build\lib\clidriver\bin\icc64\n\icc\icclib\ICCSIG.txt -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\n\icc\icclib
#   copying build\lib\clidriver\bin\icc64\n\icc\ReadMe.txt -> build\bdist.win-amd64\wheel\.\clidriver\bin\icc64\n\icc
#   creating build\bdist.win-amd64\wheel\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2ajgrt.bnd -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2cli.bnd -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2cli.lst -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2clipk.bnd -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2clist.bnd -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   copying build\lib\clidriver\bnd\db2spcdb.bnd -> build\bdist.win-amd64\wheel\.\clidriver\bnd
#   creating build\bdist.win-amd64\wheel\clidriver\cfg
#   copying build\lib\clidriver\cfg\db2dsdriver.xsd -> build\bdist.win-amd64\wheel\.\clidriver\cfg
#   copying build\lib\clidriver\cfg\DigiCertGlobalRootCA.arm -> build\bdist.win-amd64\wheel\.\clidriver\cfg
#   creating build\bdist.win-amd64\wheel\clidriver\conv
#   creating build\bdist.win-amd64\wheel\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\04370923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\08500923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\08501252.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\08600923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\08630923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09230437.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09230850.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09230860.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231043.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231051.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231114.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231208.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231252.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09231275.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09241252.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\09370950.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\10430923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\10510923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\11140923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\12080923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\12520850.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\12520923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\12750923.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\1388ucs2.cnv -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\IBM00850.ucs -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\IBM00923.ucs -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   copying build\lib\clidriver\conv\alt\IBM01252.ucs -> build\bdist.win-amd64\wheel\.\clidriver\conv\alt
#   creating build\bdist.win-amd64\wheel\clidriver\conv\ms
# ...
#   adding 'ibm_db_tests/test_053_AttrThruConn.py'
#   adding 'ibm_db_tests/test_054_CursorType.py'
#   adding 'ibm_db_tests/test_060_Tables_01.py'
#   adding 'ibm_db_tests/test_061_Tables_02.py'
#   adding 'ibm_db_tests/test_062_Tables_03.py'
#   adding 'ibm_db_tests/test_063_Tables_04.py'
#   adding 'ibm_db_tests/test_064_Tables_05.py'
#   adding 'ibm_db_tests/test_065_FilterTableName.py'
#   adding 'ibm_db_tests/test_066_TableObjects.py'
#   adding 'ibm_db_tests/test_070_Close.py'
#   adding 'ibm_db_tests/test_071_CloseSuccess.py'
#   adding 'ibm_db_tests/test_080_ConnWrongDbAlias.py'
#   adding 'ibm_db_tests/test_081_ConnWrongUser.py'
#   adding 'ibm_db_tests/test_082_ConnWrongPwd.py'
#   adding 'ibm_db_tests/test_090_ConnmsgWrongDbAlias.py'
#   adding 'ibm_db_tests/test_091_ConnmsgWrongUser.py'
#   adding 'ibm_db_tests/test_092_ConnmsgWrongPwd.py'
#   adding 'ibm_db_tests/test_100_SelectDeleteInsertFieldCount.py'
#   adding 'ibm_db_tests/test_101_InsertDeleteFieldCount.py'
#   adding 'ibm_db_tests/test_102_NumFieldsSelect_01.py'
#   adding 'ibm_db_tests/test_103_NumFieldsSelect_02.py'
#   adding 'ibm_db_tests/test_110_FieldNum.py'
#   adding 'ibm_db_tests/test_111_FieldNumAddCol.py'
#   adding 'ibm_db_tests/test_112_FieldNumDiffCaseColNames.py'
#   adding 'ibm_db_tests/test_113_DateTest.py'
#   adding 'ibm_db_tests/test_114_NumericTest_01.py'
#   adding 'ibm_db_tests/test_115_NumericTest_02.py'
#   adding 'ibm_db_tests/test_116_ConnActive.py'
#   adding 'ibm_db_tests/test_120_FieldName.py'
#   adding 'ibm_db_tests/test_121_FieldNameAddCol.py'
#   adding 'ibm_db_tests/test_122_FieldNameDiffCaseColNames.py'
#   adding 'ibm_db_tests/test_123_FieldNamePos_01.py'
#   adding 'ibm_db_tests/test_124_FieldNamePos_02.py'
#   adding 'ibm_db_tests/test_125_FieldNamePos_03.py'
#   adding 'ibm_db_tests/test_130_PrepExecuteSelectStmt.py'
#   adding 'ibm_db_tests/test_131_PrepareExecuteSelectStatementParams.py'
#   adding 'ibm_db_tests/test_132_ExecuteStatementArrayMultipleParams.py'
#   adding 'ibm_db_tests/test_133_ExecuteLongInputParams.py'
#   adding 'ibm_db_tests/test_140_BindParamSelectStmt.py'
#   adding 'ibm_db_tests/test_141_BindParamSelectStmtMultipleParams_01.py'
#   adding 'ibm_db_tests/test_142_BindParamSelectStmtMultipleParams_02.py'
#   adding 'ibm_db_tests/test_143_BindParamInsertStmtNoneParam.py'
#   adding 'ibm_db_tests/test_144_BindParamInsertStmtPARAM_FILE.py'
#   adding 'ibm_db_tests/test_145_BindRetrieveNoneEmptyString.py'
#   adding 'ibm_db_tests/test_146_CallSPINAndOUTParams.py'
#   adding 'ibm_db_tests/test_146a_CallSPINAndOUT_Blob_Param.py'
#   adding 'ibm_db_tests/test_147_PrepareWithWrongType.py'
#   adding 'ibm_db_tests/test_148_CallSPDiffBindPattern_01.py'
#   adding 'ibm_db_tests/test_150_FetchAssocSelect_01.py'
#   adding 'ibm_db_tests/test_151_FetchAssocSelect_02.py'
#   adding 'ibm_db_tests/test_152_FetchAssocSelect_03.py'
#   adding 'ibm_db_tests/test_153_FetchAssocSelect_04.py'
#   adding 'ibm_db_tests/test_154_AllFetches.py'
#   adding 'ibm_db_tests/test_155_FetchAssocSelect_05.py'
#   adding 'ibm_db_tests/test_156_FetchAssocNestedSelects_01.py'
#   adding 'ibm_db_tests/test_157_FetchAssocScrollableCursor_01.py'
#   adding 'ibm_db_tests/test_157a_FetchAssocWithoutScrollableCursorErr.py'
#   adding 'ibm_db_tests/test_157b_FetchAssocScrollableCursor_02.py'
#   adding 'ibm_db_tests/test_158_FetchAssocNestedSelects_02.py'
#   adding 'ibm_db_tests/test_159_FetchAssocSeveralRows_01.py'
#   adding 'ibm_db_tests/test_159a_FetchAssocSeveralRows_02.py'
#   adding 'ibm_db_tests/test_160_FetchBoth.py'
#   adding 'ibm_db_tests/test_161_FetchBothNestedSelects_01.py'
#   adding 'ibm_db_tests/test_162_FetchBothNestedSelects_02.py'
#   adding 'ibm_db_tests/test_180_StmtErrMsg.py'
#   adding 'ibm_db_tests/test_190_ColumnsTable_01.py'
#   adding 'ibm_db_tests/test_191_ColumnsTable_02.py'
#   adding 'ibm_db_tests/test_195_InsertRetrieveXMLData_01.py'
#   adding 'ibm_db_tests/test_196_InsertRetrieveXMLData_02.py'
#   adding 'ibm_db_tests/test_197_StatisticsIndexes.py'
#   adding 'ibm_db_tests/test_200_MultipleRsltsetsUniformColDefs.py'
#   adding 'ibm_db_tests/test_201_MultipleRsltsetsDiffColDefs.py'
#   adding 'ibm_db_tests/test_210_FieldDisplaySize_01.py'
#   adding 'ibm_db_tests/test_211_FieldDisplaySize_02.py'
#   adding 'ibm_db_tests/test_212_FieldDisplaySize_03.py'
#   adding 'ibm_db_tests/test_213_FieldDisplaySize_04.py'
#   adding 'ibm_db_tests/test_220_PersistentConn.py'
#   adding 'ibm_db_tests/test_221_100PersistentConns.py'
#   adding 'ibm_db_tests/test_230_FieldTypePos.py'
#   adding 'ibm_db_tests/test_231_FieldTypeName.py'
#   adding 'ibm_db_tests/test_232_FieldTypePosName.py'
#   adding 'ibm_db_tests/test_240_FieldWidthPosName_01.py'
#   adding 'ibm_db_tests/test_241_FieldWidthPosName_02.py'
#   adding 'ibm_db_tests/test_250_FreeResult_01.py'
#   adding 'ibm_db_tests/test_251_FreeResult_02.py'
#   adding 'ibm_db_tests/test_260_FetchTupleMany_07.py'
#   adding 'ibm_db_tests/test_261_FetchObjectAccess.py'
#   adding 'ibm_db_tests/test_264_InsertRetrieveBIGINTTypeColumn.py'
#   adding 'ibm_db_tests/test_265_NoAffectedRows.py'
#   adding 'ibm_db_tests/test_300_ServerInfo.py'
#   adding 'ibm_db_tests/test_310_ClientInfo.py'
#   adding 'ibm_db_tests/test_311_InsertSelectDeleteNumLiterals.py'
#   adding 'ibm_db_tests/test_52949_TestSPIntVarcharXml.py'
#   adding 'ibm_db_tests/test_6528_ScopingProblemBindParam.py'
#   adding 'ibm_db_tests/test_6561_InsertNULLValues.py'
#   adding 'ibm_db_tests/test_6755_ExtraNULLChar_ResultCLOBCol.py'
#   adding 'ibm_db_tests/test_6792_FieldTypeRetStrDatetimeTimestamp.py'
#   adding 'ibm_db_tests/test_InsertRetrieveDateTimeTypeColumn.py'
#   adding 'ibm_db_tests/test_SPInOutBlob.py'
#   adding 'ibm_db_tests/test_SPInOutZero.py'
#   adding 'ibm_db_tests/test_alltypes.py'
#   adding 'ibm_db_tests/test_alltypesarray.py'
#   adding 'ibm_db_tests/test_bool_callproc.py'
#   adding 'ibm_db_tests/test_booleanInsertSelect.py'
#   adding 'ibm_db_tests/test_checkBooleanType.py'
#   adding 'ibm_db_tests/test_createDropDB.py'
#   adding 'ibm_db_tests/test_createdbNX.py'
#   adding 'ibm_db_tests/test_currentschema.py'
#   adding 'ibm_db_tests/test_cursortype.py'
#   adding 'ibm_db_tests/test_decfloat.py'
#   adding 'ibm_db_tests/test_decimal.py'
#   adding 'ibm_db_tests/test_err_executemany.py'
#   adding 'ibm_db_tests/test_execute_many.py'
#   adding 'ibm_db_tests/test_recreateDB.py'
#   adding 'ibm_db_tests/test_setgetOption.py'
#   adding 'ibm_db_tests/test_trusted_context_connect.py'
#   adding 'ibm_db_tests/test_trusted_context_pconnect.py'
#   adding 'ibm_db_tests/test_unicodeTable.py'
#   adding 'ibm_db_tests/test_warn.py'
#   adding 'ibm_db-3.1.4.dist-info/LICENSE'
#   adding 'ibm_db-3.1.4.dist-info/METADATA'
#   adding 'ibm_db-3.1.4.dist-info/WHEEL'
#   adding 'ibm_db-3.1.4.dist-info/top_level.txt'
#   adding 'ibm_db-3.1.4.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   [WinError 145] The directory is not empty: 'build\\bdist.win-amd64\\wheel\\clidriver'
#   error: [WinError 145] The directory is not empty: 'build\\bdist.win-amd64\\wheel\\clidriver'
#   ----------------------------------------
#   ERROR: Failed building wheel for ibm-db
# ERROR: Could not build wheels for ibm-db which use PEP 517 and cannot be installed directly
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 98, in main
#     return self._main(args)
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 126, in __exit__
#     next(self.gen)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\cli\command_context.py", line 20, in main_context
#     yield
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 532, in __exit__
#     raise exc_details[1]
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\utils\temp_dir.py", line 75, in tempdir_registry
#     yield _tempdir_registry
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 517, in __exit__
#     if cb(*exc_details):
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 126, in __exit__
#     next(self.gen)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\utils\temp_dir.py", line 37, in global_tempdir_manager
#     _tempdir_manager = old_tempdir_manager
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 532, in __exit__
#     raise exc_details[1]
#   File "C:\Users\User\anaconda3\lib\contextlib.py", line 517, in __exit__
#     if cb(*exc_details):
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\utils\temp_dir.py", line 165, in __exit__
#     self.cleanup()
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\utils\temp_dir.py", line 184, in cleanup
#     rmtree(self._path)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 326, in wrapped_f
#     return self(f, *args, **kw)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 406, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 362, in iter
#     raise retry_exc.reraise()
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 195, in reraise
#     raise self.last_attempt.result()
#   File "C:\Users\User\anaconda3\lib\concurrent\futures\_base.py", line 439, in result
#     return self.__get_result()
#   File "C:\Users\User\anaconda3\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 409, in __call__
#     result = fn(*args, **kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 135, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors, onerror=rmtree_errorhandler)
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 757, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 622, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 622, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 622, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   [Previous line repeated 3 more times]
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 608, in _rmtree_unsafe
#     onerror(os.scandir, path, sys.exc_info())
#   File "C:\Users\User\anaconda3\lib\shutil.py", line 605, in _rmtree_unsafe
#     with os.scandir(path) as scandir_it:
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\User\\AppData\\Local\\Temp\\pip-install-71jk6752\\ibm-db_f90b4cf759d2408b85a5147281e82671\\build\\bdist.win-amd64\\wheel\\clidriver\\bin'
# Collecting ipython-sql
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (8.2.0)
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Collecting prettytable
#   Downloading prettytable-3.6.0-py3-none-any.whl (27 kB)
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.7-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (61.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-sql) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Installing collected packages: typing-extensions, sqlparse, sqlalchemy, prettytable, ipython-sql
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# Successfully installed ipython-sql-0.5.0 prettytable-3.6.0 sqlalchemy-2.0.7 sqlparse-0.4.3 typing-extensions-4.5.0

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# **DB2 magic in case of old UI service credentials.**
#
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance before. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">
#
# in the following format
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name**
#
# **DB2 magic in case of new UI service credentials.**
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width=600>
#
# *   Use the following format.
#
# *   Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name?security=SSL**

# %%
# %sql ibm_db_sa://dmk94268:T0OsLnIy2r4JsLzw@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/db2://dmk94268:T0OsLnIy2r4JsLzw@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb?authSource=admin&replicaSet=replset?security=SSL
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 277, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 551, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 365, in load
#     raise exc.NoSuchModuleError(
# sqlalchemy.exc.NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:ibm_db_sa
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 277, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 551, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "C:\Users\User\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 365, in load
#     raise exc.NoSuchModuleError(
# sqlalchemy.exc.NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:ibm_db_sa
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql SELECT DISTINCT LAUNCH_SITE as "Launch_Sites" FROM SPACEXTBL;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql SELECT LAUNCH_SITE FROM SPACEXTBL WHERE LAUNCH_SITE LIKE 'CCA%' LIMIT 5;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql SELECT SUM (PAYLOAD_MASS__kg_) FROM SPACEXTBL WHERE CUSTOMER = 'NASA(CRS)' ;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql SELECT AVERAGE (PAYLOAD_MASS__KG_) FROM SPACEXTBL WHERE BOOSTER_VERSION = 'F9 v1.1';
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
# *Hint:Use min function*

# %%
# %sql SELECT MIN (DATE) AS "First Successful Landing" FROM SPACEXTBL WHERE LANDING_OUTCOME = 'Success (ground pad)';
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql SELECT BOOSTER_VERSION FROM SPACEXTBL WHERE LANDING_OUTCOME = 'Success (drone ship)' AND PAYLOAD_MASS__KG_ > 4000 AND PAYLOAD_MASS__KG_ < 6000
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql SELECT COUNT MISSION_OUTCOME AS "succesful mission "FROM SPACEXTBL WHERE MISSION_OUTCOME LIKE 'Success%'
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql SELECT COUNT MISSION_OUTCOME AS "failure mission " FROM SPACEXTBL WHERE MISSION_OUTCOME LIKE 'Fail%'
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql SELECT sum(case when MISSION_OUTCOME LIKE '%Success%' then 1 else 0 end) AS "Successful Mission", \
    sum(case when MISSION_OUTCOME LIKE '%Failure%' then 1 else 0 end) AS "Failure Mission" \
FROM SPACEXTBL;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql SELECT DISTINCT BOOSTER_VERSION AS "Booster Versions which carried the Maximum Payload Mass" FROM SPACEXTBL \
WHERE PAYLOAD_MASS__KG_ =(SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTBL);
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 9
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %%
# %sql SELECT BOOSTER_VERSION, LAUNCH_SITE FROM SPACEXTBL WHERE DATE LIKE '2015-%' AND \
LANDING__OUTCOME = 'Failure (drone ship)';
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %%
# %sql SELECT LANDING__OUTCOME as "Landing Outcome", COUNT(LANDING__OUTCOME) AS "Total Count" FROM SPACEX \
WHERE DATE BETWEEN '2010-06-04' AND '2017-03-20' \
GROUP BY  LANDING__OUTCOME \
ORDER BY COUNT(LANDING__OUTCOME) DESC ;
# Out:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\User\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Reference Links
#
# *   <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01&origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01&origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01&origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *   <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
#
# | Date       | Version | Changed by    | Change Description        |
# | ---------- | ------- | ------------- | ------------------------- |
# | 2021-10-12 | 0.4     | Lakshmi Holla | Changed markdown          |
# | 2021-08-24 | 0.3     | Lakshmi Holla | Added library update      |
# | 2021-07-09 | 0.2     | Lakshmi Holla | Changes made in magic sql |
# | 2021-05-20 | 0.1     | Lakshmi Holla | Created Initial Version   |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
